# %%
import pandas as pd 
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('C:/Users/User/Desktop/compozent internship aiml/ML task/netflix_titles.csv')
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.drop(columns=['description', 'date_added', 'listed_in', 'show_id', ], inplace=True)

# %%
df.head(100)
# Out:
#        type                                              title  \
# 0     Movie                               Dick Johnson Is Dead
# 1   TV Show                                      Blood & Water
# 2   TV Show                                          Ganglands
# 3   TV Show                              Jailbirds New Orleans
# 4   TV Show                                       Kota Factory
# ..      ...                                                ...
# 95  TV Show                                         The Circle
# 96    Movie  If I Leave Here Tomorrow: A Film About Lynyrd ...
# 97  TV Show                                         Kid Cosmic
# 98  TV Show                          Octonauts: Above & Beyond
# 99  TV Show                                       On the Verge
#
#            director                                               cast  \
# 0   Kirsten Johnson                                                NaN
# ...

# %%
df.drop(columns='cast' , inplace=True)

# %%
df.head(100)
# Out:
#        type                                              title  \
# 0     Movie                               Dick Johnson Is Dead
# 1   TV Show                                      Blood & Water
# 2   TV Show                                          Ganglands
# 3   TV Show                              Jailbirds New Orleans
# 4   TV Show                                       Kota Factory
# ..      ...                                                ...
# 95  TV Show                                         The Circle
# 96    Movie  If I Leave Here Tomorrow: A Film About Lynyrd ...
# 97  TV Show                                         Kid Cosmic
# 98  TV Show                          Octonauts: Above & Beyond
# 99  TV Show                                       On the Verge
#
#            director                        country  release_year rating  \
# 0   Kirsten Johnson                  United States          2020  PG-13
# ...

# %%
df.drop(columns='duration', inplace=True)

# %%
le = LabelEncoder()

df['type'] = le.fit_transform(df['type'])
df['country'] = le.fit_transform(df['country']) 
df['rating'] = le.fit_transform(df['rating'])
df['director'] = le.fit_transform(df['director'])
df['title'] = le.fit_transform(df['title'])

# %%
df.head(5)
# Out:
#    type  title  director  country  release_year  rating
# 0     0   1975      2295      603          2020       7
# 1     1   1091      4528      426          2021      11
# 2     1   2651      2105      748          2021      11
# 3     1   3506      4528      748          2021      11
# 4     1   3861      4528      251          2021      11

# %%
X = df[['type', 'director', 'country', 'release_year', 'rating']]
Y = df['title']

# %%
X_train , X_test, Y_train, Y_test = train_test_split(X,Y,train_size=0.2)

# %%
model = DecisionTreeRegressor()
model.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
Y_pred = model.predict(X_test)
print(Y_pred)
# Out:
# [5346. 5641. 7307. ... 6354. 5695.  260.]

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
me = mean_absolute_error(Y_test, Y_pred)
print("Mean Absolute Error:", me)


r2 = r2_score(Y_test, Y_pred)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 2846.8991837651893
# R-squared: -0.919736142422356

# %%
with open('C:/Users/User/Desktop/compozent internship aiml/ML task/netflix_model.pkl', 'wb') as f:
    pickle.dump(model,f)
